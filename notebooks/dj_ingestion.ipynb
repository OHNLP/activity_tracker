# %%
import datajoint as dj
from activity_tracker.pipeline import subject, models, ingestion, visit, measurement

subject.Subject()

# %%
visit.Visit()

# %%
measurement.Frailty()

# %%
measurement.Frailty()

# %%
measurement.Frailty()

# %%
measurement.DailyMeasurement()

# %%
models.Feature()

# %%
ingestion.ingest_features(feature_id=3)

# %%
feature_df = models.Feature.get_feature_matrix(3)
feature_df.head()

# %%
feature_df.columns

# %%
feature_df[["subject_id", "start_date", "measurement_date", "interval_length", "missing_days_pct"]].to_csv("features.csv", index=False)

# %%
test = feature_df[["subject_id", "start_date", "measurement_date", "interval_length", "missing_days_pct"]]
