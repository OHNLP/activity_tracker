# %%
import datajoint as dj
from activity_tracker.pipeline import subject

subject.Subject.ingest()
# Out:
# [2025-07-02 14:39:47,968][INFO]: DataJoint 0.14.4 connected to root@localhost:3306
# Inserted 89 subject records

# %%
subject.Subject()
# Out:
# *subject_id    group        sex     age       ethnicity     race            monthly_income     education     marital_status     living_situation
# +------------+ +----------+ +-----+ +-------+ +-----------+ +-------------+ +----------------+ +-----------+ +----------------+ +------------------+
# MDE001         control      m       83.0      non_hisp      black           3000.0             18.0          never_married      with_others
# MDE002         exercise     m       61.0      non_hisp      white           1033.0             3.0           never_married      alone
# MDE003         exercise     f       69.0      hisp          white           1349.0             13.0          widowed            with_family
# MDE004         control      f       65.0      non_hisp      black           900.0              11.0          widowed            with_family
# ...
